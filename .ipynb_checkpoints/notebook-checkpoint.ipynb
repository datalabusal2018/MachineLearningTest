# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Guardamos la base de datos en una variable

# %%
train = pd.read_csv('train.csv')

# %% [markdown]
# Observamos si la tabla está correcta

# %%
train.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca  thal  num
# 0    3.0  0.0   6.0    0
# 1    2.0  3.0   3.0    2
# 2    2.0  2.0   7.0    1
# 3    3.0  0.0   3.0    0
# 4    1.0  0.0   3.0    0

# %% [markdown]
# Eliminamos los NaN con mean()

# %%
train = train.fillna(train.mean())

# %%
train
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# 5    56.0  1.0  2.0     120.0  236.0  0.0      0.0    178.0    0.0      0.8
# 6    62.0  0.0  4.0     140.0  268.0  0.0      2.0    160.0    0.0      3.6
# 7    57.0  0.0  4.0     120.0  354.0  0.0      0.0    163.0    1.0      0.6
# 8    63.0  1.0  4.0     130.0  254.0  0.0      2.0    147.0    0.0      1.4
# 9    53.0  1.0  4.0     140.0  203.0  1.0      2.0    155.0    1.0      3.1
# 10   57.0  1.0  4.0     140.0  192.0  0.0      0.0    148.0    0.0      0.4
# ...

# %% [markdown]
# Recombinamos la variable num que define el tipo de enfermedad en booleana para distinguir entre enfermos y no enfermos

# %%
for i, val in enumerate(train.num):
    if val != 0:
        train.num[i] = 1
# Out:
# C:\Users\Jesus\PythonConda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# Verificamos el cambio

# %%
train.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca  thal  num
# 0    3.0  0.0   6.0    0
# 1    2.0  3.0   3.0    1
# 2    2.0  2.0   7.0    1
# 3    3.0  0.0   3.0    0
# 4    1.0  0.0   3.0    0

# %% [markdown]
# Definimos las matrices para iniciar el entrenamiento

# %%
x, y = train.iloc[:,:-1], train.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.33, random_state=47)

# %%
x_train.head()
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 85   44.0  1.0  3.0     140.0  235.0  0.0      2.0    180.0    0.0      0.0
# 248  52.0  1.0  4.0     125.0  212.0  0.0      0.0    168.0    0.0      1.0
# 228  54.0  1.0  4.0     110.0  206.0  0.0      2.0    108.0    1.0      0.0
# 102  57.0  0.0  4.0     128.0  303.0  0.0      2.0    159.0    0.0      0.0
# 213  66.0  0.0  4.0     178.0  228.0  1.0      0.0    165.0    1.0      1.0
#
#      slope   ca  thal
# 85     1.0  0.0   3.0
# 248    1.0  2.0   7.0
# 228    2.0  1.0   3.0
# 102    1.0  1.0   3.0
# 213    2.0  2.0   7.0

# %% [markdown]
# Empezemos con la regresión logística para la clasificación de nuestras variables

# %%
from sklear.linear_model import LogisticRegression
