# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('C:\\Users\\udec1\\Datalab\\MachineLearningTest\\data\\train.csv')

# %%
train.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca  thal  num
# 0    3.0  0.0   6.0    0
# 1    2.0  3.0   3.0    2
# 2    2.0  2.0   7.0    1
# 3    3.0  0.0   3.0    0
# 4    1.0  0.0   3.0    0

# %%
train = train.fillna(0)

# %% [markdown]
# ### Bucle for

# %%
for el in train.num:
    print(el)
# Out:
# 0
# 2
# 1
# 0
# 0
# 0
# 3
# 0
# 2
# 1
# 0
# 0
# 2
# 0
# 0
# 0
# 1
# 0
# 0
# 0
# 0
# 0
# 1
# 3
# 4
# 0
# 0
# 0
# 0
# 3
# 0
# 2
# 1
# 0
# 0
# 0
# 3
# 1
# 3
# 0
# 4
# 0
# 0
# 0
# 1
# 4
# 0
# 4
# 0
# 0
# 0
# 0
# 2
# 0
# 1
# 1
# 1
# 1
# 0
# 0
# 2
# 0
# 1
# 0
# 2
# 2
# 1
# 0
# 2
# 1
# 0
# 3
# 1
# 1
# 1
# 0
# 1
# 0
# 0
# 3
# 0
# 0
# 0
# 3
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 3
# 0
# 0
# 0
# 1
# 2
# 3
# 0
# 0
# 0
# 0
# 0
# 0
# 3
# 0
# 2
# 1
# 2
# 3
# 1
# 1
# 0
# 2
# 2
# 0
# 0
# 0
# 3
# 2
# 3
# 4
# 0
# 3
# 1
# 0
# 3
# 3
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 4
# 3
# 1
# 0
# 0
# 1
# 0
# 1
# 0
# 1
# 4
# 0
# 0
# 0
# 0
# 0
# 0
# 4
# 3
# 1
# 1
# 1
# 2
# 0
# 0
# 4
# 0
# 0
# 0
# 0
# 0
# 0
# 1
# 0
# 3
# 0
# 1
# 0
# 4
# 1
# 0
# 1
# 0
# 0
# 3
# 2
# 0
# 0
# 1
# 0
# 0
# 2
# 1
# 2
# 0
# 3
# 1
# 2
# 0
# 3
# 0
# 0
# 0
# 1
# 0
# 0
# 0
# 0
# 0
# 3
# 3
# 3
# 0
# 1
# 0
# 4
# 0
# 3
# 1
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 3
# 1
# 0
# 0
# 0
# 3
# 2
# 0
# 2
# 1
# 0
# 0
# 3
# 2
# 1
# 0
# 0
# 0
# 0
# 0
# 2
# 0
# 2
# 2
# 1
# 3
# 0
# ...

# %%
for i in range(len(train.num)):
    print(train.iloc[i,-1])
# Out:
# 0
# 2
# 1
# 0
# 0
# 0
# 3
# 0
# 2
# 1
# 0
# 0
# 2
# 0
# 0
# 0
# 1
# 0
# 0
# 0
# 0
# 0
# 1
# 3
# 4
# 0
# 0
# 0
# 0
# 3
# 0
# 2
# 1
# 0
# 0
# 0
# 3
# 1
# 3
# 0
# 4
# 0
# 0
# 0
# 1
# 4
# 0
# 4
# 0
# 0
# 0
# 0
# 2
# 0
# 1
# 1
# 1
# 1
# 0
# 0
# 2
# 0
# 1
# 0
# 2
# 2
# 1
# 0
# 2
# 1
# 0
# 3
# 1
# 1
# 1
# 0
# 1
# 0
# 0
# 3
# 0
# 0
# 0
# 3
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 3
# 0
# 0
# 0
# 1
# 2
# 3
# 0
# 0
# 0
# 0
# 0
# 0
# 3
# 0
# 2
# 1
# 2
# 3
# 1
# 1
# 0
# 2
# 2
# 0
# 0
# 0
# 3
# 2
# 3
# 4
# 0
# 3
# 1
# 0
# 3
# 3
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 4
# 3
# 1
# 0
# 0
# 1
# 0
# 1
# 0
# 1
# 4
# 0
# 0
# 0
# 0
# 0
# 0
# 4
# 3
# 1
# 1
# 1
# 2
# 0
# 0
# 4
# 0
# 0
# 0
# 0
# 0
# 0
# 1
# 0
# 3
# 0
# 1
# 0
# 4
# 1
# 0
# 1
# 0
# 0
# 3
# 2
# 0
# 0
# 1
# 0
# 0
# 2
# 1
# 2
# 0
# 3
# 1
# 2
# 0
# 3
# 0
# 0
# 0
# 1
# 0
# 0
# 0
# 0
# 0
# 3
# 3
# 3
# 0
# 1
# 0
# 4
# 0
# 3
# 1
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 3
# 1
# 0
# 0
# 0
# 3
# 2
# 0
# 2
# 1
# 0
# 0
# 3
# 2
# 1
# 0
# 0
# 0
# 0
# 0
# 2
# 0
# 2
# 2
# 1
# 3
# 0
# ...

# %% [markdown]
# ## IF

# %%
if train.num[34] != 0:
    print('No es cero')
else:
    print('Es cero')
# Out:
# Es cero

# %%
print(train.num[34])
# Out:
# 0

# %% [markdown]
# ## Transformar train.num

# %%
for i in range(len(train.num)):
    if train.num[i] !=0:
        train.iloc[i,-1] = 1

# %%
train.iloc[:3,:3]
# Out:
#     age  sex   cp
# 0  63.0  1.0  1.0
# 1  67.0  1.0  4.0
# 2  67.0  1.0  4.0

# %%
train.loc[1,'sex']
# Out:
# 1.0

# %% [markdown]
# ## Regresión logística

# %%
X, y = train.iloc[:,:-1], train.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=50)

# %%
display(X_train)
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 97   60.0  0.0  4.0     150.0  258.0  0.0      2.0    157.0    0.0      2.6
# 221  54.0  0.0  3.0     108.0  267.0  0.0      2.0    167.0    0.0      0.0
# 99   48.0  1.0  4.0     122.0  222.0  0.0      2.0    186.0    0.0      0.0
# 225  34.0  0.0  2.0     118.0  210.0  0.0      0.0    192.0    0.0      0.7
# 114  62.0  0.0  3.0     130.0  263.0  0.0      0.0     97.0    0.0      1.2
# 61   46.0  0.0  3.0     142.0  177.0  0.0      2.0    160.0    1.0      1.4
# 211  38.0  1.0  1.0     120.0  231.0  0.0      0.0    182.0    1.0      3.8
# 194  68.0  0.0  3.0     120.0  211.0  0.0      2.0    115.0    0.0      1.5
# 127  54.0  1.0  4.0     110.0  239.0  0.0      0.0    126.0    1.0      2.8
# 215  56.0  1.0  1.0     120.0  193.0  0.0      2.0    162.0    0.0      1.9
# 197  45.0  0.0  4.0     138.0  236.0  0.0      2.0    152.0    1.0      0.2
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
logistic = LogisticRegression()

# %%
y_pred = logistic.fit(X_train, y_train).predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[51,  2],
#        [ 7, 28]], dtype=int64)
