# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('C:\\Users\\Usuario\\DATALAB\\MachineLearningTest\\data\\train.csv')

# %%
train.head(6)
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# 5  56.0  1.0  2.0     120.0  236.0  0.0      0.0    178.0    0.0      0.8
#
#    slope   ca  thal  num
# 0    3.0  0.0   6.0    0
# 1    2.0  3.0   3.0    2
# 2    2.0  2.0   7.0    1
# 3    3.0  0.0   3.0    0
# 4    1.0  0.0   3.0    0
# 5    1.0  0.0   3.0    0

# %%
train = train.fillna(0)

# %% [markdown]
# ### Bucle For

# %%
for el in train.num:
    print(el)
# Out:
# 0
# 2
# 1
# 0
# 0
# 0
# 3
# 0
# 2
# 1
# 0
# 0
# 2
# 0
# 0
# 0
# 1
# 0
# 0
# 0
# 0
# 0
# 1
# 3
# 4
# 0
# 0
# 0
# 0
# 3
# 0
# 2
# 1
# 0
# 0
# 0
# 3
# 1
# 3
# 0
# 4
# 0
# 0
# 0
# 1
# 4
# 0
# 4
# 0
# 0
# 0
# 0
# 2
# 0
# 1
# 1
# 1
# 1
# 0
# 0
# 2
# 0
# 1
# 0
# 2
# 2
# 1
# 0
# 2
# 1
# 0
# 3
# 1
# 1
# 1
# 0
# 1
# 0
# 0
# 3
# 0
# 0
# 0
# 3
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 3
# 0
# 0
# 0
# 1
# 2
# 3
# 0
# 0
# 0
# 0
# 0
# 0
# 3
# 0
# 2
# 1
# 2
# 3
# 1
# 1
# 0
# 2
# 2
# 0
# 0
# 0
# 3
# 2
# 3
# 4
# 0
# 3
# 1
# 0
# 3
# 3
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 4
# 3
# 1
# 0
# 0
# 1
# 0
# 1
# 0
# 1
# 4
# 0
# 0
# 0
# 0
# 0
# 0
# 4
# 3
# 1
# 1
# 1
# 2
# 0
# 0
# 4
# 0
# 0
# 0
# 0
# 0
# 0
# 1
# 0
# 3
# 0
# 1
# 0
# 4
# 1
# 0
# 1
# 0
# 0
# 3
# 2
# 0
# 0
# 1
# 0
# 0
# 2
# 1
# 2
# 0
# 3
# 1
# 2
# 0
# 3
# 0
# 0
# 0
# 1
# 0
# 0
# 0
# 0
# 0
# 3
# 3
# 3
# 0
# 1
# 0
# 4
# 0
# 3
# 1
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 3
# 1
# 0
# 0
# 0
# 3
# 2
# 0
# 2
# 1
# 0
# 0
# 3
# 2
# 1
# 0
# 0
# 0
# 0
# 0
# 2
# 0
# 2
# 2
# 1
# 3
# 0
# ...

# %% [markdown]
# ### mismo bucle For

# %%
for i in range(len(train.num)):
    print(train.iloc[i,-1])
# Out:
# 0
# 2
# 1
# 0
# 0
# 0
# 3
# 0
# 2
# 1
# 0
# 0
# 2
# 0
# 0
# 0
# 1
# 0
# 0
# 0
# 0
# 0
# 1
# 3
# 4
# 0
# 0
# 0
# 0
# 3
# 0
# 2
# 1
# 0
# 0
# 0
# 3
# 1
# 3
# 0
# 4
# 0
# 0
# 0
# 1
# 4
# 0
# 4
# 0
# 0
# 0
# 0
# 2
# 0
# 1
# 1
# 1
# 1
# 0
# 0
# 2
# 0
# 1
# 0
# 2
# 2
# 1
# 0
# 2
# 1
# 0
# 3
# 1
# 1
# 1
# 0
# 1
# 0
# 0
# 3
# 0
# 0
# 0
# 3
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 3
# 0
# 0
# 0
# 1
# 2
# 3
# 0
# 0
# 0
# 0
# 0
# 0
# 3
# 0
# 2
# 1
# 2
# 3
# 1
# 1
# 0
# 2
# 2
# 0
# 0
# 0
# 3
# 2
# 3
# 4
# 0
# 3
# 1
# 0
# 3
# 3
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 4
# 3
# 1
# 0
# 0
# 1
# 0
# 1
# 0
# 1
# 4
# 0
# 0
# 0
# 0
# 0
# 0
# 4
# 3
# 1
# 1
# 1
# 2
# 0
# 0
# 4
# 0
# 0
# 0
# 0
# 0
# 0
# 1
# 0
# 3
# 0
# 1
# 0
# 4
# 1
# 0
# 1
# 0
# 0
# 3
# 2
# 0
# 0
# 1
# 0
# 0
# 2
# 1
# 2
# 0
# 3
# 1
# 2
# 0
# 3
# 0
# 0
# 0
# 1
# 0
# 0
# 0
# 0
# 0
# 3
# 3
# 3
# 0
# 1
# 0
# 4
# 0
# 3
# 1
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 3
# 1
# 0
# 0
# 0
# 3
# 2
# 0
# 2
# 1
# 0
# 0
# 3
# 2
# 1
# 0
# 0
# 0
# 0
# 0
# 2
# 0
# 2
# 2
# 1
# 3
# 0
# ...

# %% [markdown]
# ### Bucle If

# %%
if train.num[34] !=0:
    print("No cero")
else:
    print("Es cero")
# Out:
# Es cero

# %%
print(train.num[34])
# Out:
# 0

# %% [markdown]
# ### Transformación de última columna

# %%
for i in range(len(train.num)):
    if train.num[i] !=0:
        train.iloc[i,-1] = 1

# %%
display(train.num)
# Out:
# 0      0
# 1      1
# 2      1
# 3      0
# 4      0
# 5      0
# 6      1
# 7      0
# 8      1
# 9      1
# 10     0
# 11     0
# 12     1
# 13     0
# 14     0
# 15     0
# 16     1
# 17     0
# 18     0
# 19     0
# 20     0
# 21     0
# 22     1
# 23     1
# 24     1
# 25     0
# 26     0
# 27     0
# 28     0
# 29     1
#       ..
# 234    0
# 235    1
# 236    1
# 237    1
# 238    0
# 239    0
# 240    0
# 241    0
# 242    0
# 243    1
# 244    0
# 245    1
# 246    1
# 247    1
# 248    1
# 249    0
# 250    0
# 251    1
# 252    0
# 253    0
# 254    0
# 255    0
# 256    0
# 257    0
# 258    0
# 259    1
# 260    0
# 261    1
# 262    0
# 263    0
# Name: num, Length: 264, dtype: int64

# %%
train.iloc[:3,:3]
# Out:
#     age  sex   cp
# 0  63.0  1.0  1.0
# 1  67.0  1.0  4.0
# 2  67.0  1.0  4.0

# %%
train.loc[1,"sex"]
# Out:
# 1.0

# %% [markdown]
# ### echar un vistazo a los gráficos de panda

# %%
X, y = train.iloc[:,:-1], train.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
display(X_train)
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 228  54.0  1.0  4.0     110.0  206.0  0.0      2.0    108.0    1.0      0.0
# 92   62.0  1.0  3.0     130.0  231.0  0.0      0.0    146.0    0.0      1.8
# 162  54.0  0.0  3.0     110.0  214.0  0.0      0.0    158.0    0.0      1.6
# 255  42.0  0.0  3.0     120.0  209.0  0.0      0.0    173.0    0.0      0.0
# 117  35.0  0.0  4.0     138.0  183.0  0.0      0.0    182.0    0.0      1.4
# 29   40.0  1.0  4.0     110.0  167.0  0.0      2.0    114.0    1.0      2.0
# 200  50.0  0.0  4.0     110.0  254.0  0.0      2.0    159.0    0.0      0.0
# 180  48.0  1.0  4.0     124.0  274.0  0.0      2.0    166.0    0.0      0.5
# 97   60.0  0.0  4.0     150.0  258.0  0.0      2.0    157.0    0.0      2.6
# 104  49.0  1.0  3.0     120.0  188.0  0.0      0.0    139.0    0.0      2.0
# 5    56.0  1.0  2.0     120.0  236.0  0.0      0.0    178.0    0.0      0.8
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
logistic = LogisticRegression()

# %%
y_pred = logistic.fit(X_train, y_train).predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[40,  4],
#        [10, 34]], dtype=int64)
